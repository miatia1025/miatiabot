# %%
channels = '''
[
  '1086301396934074499', '1086308521483698387', '1086309255881166972',
  '1086311796220100679', '1086314353642442752', '1086314614943395920',
  '1086315162996322367', '1086322455003533322', '1086325070080786573',
  '1086326580143468545', '1086327037448429689', '1086327660352901312',
  '1086327724995518575', '1086327830171885609', '1086329997096128612',
  '1086346496791822408', '1086347173429522522', '1086347405114474706',
  '1086349095788101707', '1086351403670319136', '1086353629767806996',
  '1086353699074482279', '1086353820365377566', '1086358589679091712',
  '1086661326639730760', '1090479077871329310', '1090479180153622538',
  '1090489040450637895', '1090661415381110794', '1090661585506291832',
  '1090674688096751687', '1090677180222144613', '1090677422824902767',
  '1090677510301302935', '1090677551984283679', '1090693748998017147',
  '1090693816866050181', '1090796252020609054', '1090797299355107449',
  '1090801491041865748', '1090807842375729284', '1090826585218748476',
  '1090834189600968704', '1090836049242116198', '1090836116569079828',
  '1090836427731898369', '1091019997695987763', '1091035725039943722',
  '1091067099952189440', '1091185393149431899', '1091197608820748348',
  '1091293213094055986', '1091362301581479976', '1091364627541139608',
  '1091578612446150658', '1091720577305288846', '1091987462424891523',
  '1092092707205287957', '1092099226084847708', '1092327962071810148',
  '1092348770936705105', '1092463338048462908', '1092464785066569809',
  '1092629286697042083', '1092822854137040896', '1093185827519090808',
  '1093194041178472519', '1093538057673773166', '1093543768306765834',
  '1093549379673149451', '1093560034509734078', '1093561752643457084',
  '1093562369315184832', '1093611580270325902', '1093624872678207508',
  '1093707648182005825', '1093778363824484352'
]
'''

# %%
import ast

merged_arr = ast.literal_eval(channels)
sorted_arr = sorted(merged_arr, key=int)

print(sorted_arr)

# %%
## User Input

dir_path = r"E:\AI\miatiadev\discord_ids\frontend\exports\discord-niji"
filename = r"discord-mini1"

## User Input End

import os
import shutil
import subprocess
import datetime

# get files
all_files = []
for root, dirs, files in os.walk(dir_path):
    for file in files + dirs:
        all_files.append(os.path.join(root, file))

# create filename
now = datetime.date.today()
formatted_date = now.strftime("%Y-%m%d")

archive_name = f"{filename}-{formatted_date}.7z"
print(archive_name)

# %%
path = r"E:\AI\miatiadev\miatiabot\Cli\DiscordChatExporter.Cli.dll"
output_path = r"E:\AI\miatiadev\miatiabot\frontend\exports\discord-mini1"
file_format = r"JSON"

from dotenv import dotenv_values
config = dotenv_values(".env")
token = config["BOT_TOKEN"]
print(token)

for channel_id in sorted_arr:
    print(channel_id)
    # !dotnet $path export -c $channel_id -f $file_format -t $token -o $output_path --media --reuse-media

# %% [markdown]
# ## niji用

# %%
eng_channels = '''
[
  '1022054419510075402', '1044842408602513448', '1045602394425282580',
  '1051067660013674496', '1051067680255393862', '1054962536002371604',
  '1054962560941694997', '1086322455003533322', '1086325070080786573',
]
'''

jp_channels = '''
[
  '1022054094476673085', '1045601907823087626', '1045601954576994354',
  '1051067701960921129', '1051067740665946132', 
]
'''

kr_channels = '''
[
  '1022054381870395432', '1046289486126002246', '1046289514026516520',
  '1051067777881997403', '1051067796102053938', 
]
'''

ch_channels = '''
[
  '1022745052944007198', '1046289365619458108', '1046289392974704660',
  '1051067814305333268', '1051067840976916530', 
]
'''

# %%
eng_threads = '''
[

]
'''

jp_threads = '''
[

]
'''

kr_threads = '''
[

]
'''

ch_threads = '''
[

]
'''

# %%
import ast

merged_arr = ast.literal_eval(eng_channels) + ast.literal_eval(jp_channels) + ast.literal_eval(kr_channels) + ast.literal_eval(ch_channels)
sorted_arr = sorted(merged_arr, key=int)

print(sorted_arr)
# Out:
# ['1022054094476673085', '1022054381870395432', '1022054419510075402', '1022745052944007198', '1044842408602513448', '1045601907823087626', '1045601954576994354', '1045602394425282580', '1046289365619458108', '1046289392974704660', '1046289486126002246', '1046289514026516520', '1051067660013674496', '1051067680255393862', '1051067701960921129', '1051067740665946132', '1051067777881997403', '1051067796102053938', '1051067814305333268', '1051067840976916530', '1054962536002371604', '1054962560941694997', '1086322455003533322', '1086325070080786573']

# %%
## User Input

dir_path = r"E:\AI\miatiadev\miatiabot\frontend\exports\discord-niji"
filename = r"discord-niji"

## User Input End

import os
import shutil
import subprocess
import datetime

# get files
all_files = []
for root, dirs, files in os.walk(dir_path):
    for file in files + dirs:
        all_files.append(os.path.join(root, file))

# create filename
now = datetime.date.today()
formatted_date = now.strftime("%Y-%m%d")

archive_name = f"{filename}-{formatted_date}.7z"
print(archive_name)
# Out:
# discord-niji-2023-0408.7z

# %%
path = r"E:\AI\miatiadev\miatiabot\Cli\DiscordChatExporter.Cli.dll"
output_path = r"D:\DiscordNiji\discord-niji"
file_format = r"JSON"

datefrom = r"2023-04-02 23:59"

from dotenv import dotenv_values
config = dotenv_values(".env")
token = config["USER_TOKEN"]
print(token)

for channel_id in sorted_arr:
    print(channel_id)
    # !dotnet $path export -c $channel_id -f $file_format -t $token -o $output_path --media --reuse-media --after ${datefrom}
# Out:
# MzY2ODE0NTA3Nzg1MjU2OTcw.G9ckgY.iyU5u7-Ziq7Eo0yduFpNCCQSBQU_jrn_ZmlbBQ
# 1022054094476673085
#
# DiscordChatExporter.Cli v2.39.1
#
# USAGE
#   dotnet DiscordChatExporter.Cli.dll export --channel <values...> --token <value> [options]
#
# DESCRIPTION
#   Export one or multiple channels.
#
# OPTIONS
# * -c|--channel      Channel ID(s). If provided with category IDs, all channels inside those categories will be exported.
# * -t|--token        Authentication token. Environment variable: DISCORD_TOKEN.
#   -o|--output       Output file or directory path. If a directory is specified, file names will be generated automatically based on the channel names and other parameters. Directory path should end with a slash to avoid ambiguity. Supports template tokens, see the documentation for more info. Default: "e:\AI\miatiadev\miatiabot".
#   -f|--format       Export format. Choices: "PlainText", "HtmlDark", "HtmlLight", "Csv", "Json". Default: "HtmlDark".
#   --after           Only include messages sent after this date or message ID.
#   --before          Only include messages sent before this date or message ID.
#   -p|--partition    Split output into partitions, each limited to this number of messages (e.g. '100') or file size (e.g. '10mb').
#   --filter          Only include messages that satisfy this filter (e.g. 'from:foo#1234' or 'has:image').
#   --parallel        Limits how many channels can be exported in parallel. Default: "1".
#   --markdown        Process markdown, mentions, and other special tokens. Default: "True".
#   --media           Download assets referenced by the export (user avatars, attached files, embedded images, etc.). Default: "False".
#   --reuse-media     Reuse previously downloaded assets to avoid redundant requests. Default: "False".
#   --media-dir       Download assets to this directory. If not specified, the asset directory path will be derived from the output path.
#   --dateformat      Format used when writing dates. Default: "MM/dd/yyyy h:mm tt".
#   --fuck-russia     Don't print the Support Ukraine message to the console. Default: "False".
#   -b|--bot          This option doesn't do anything. Kept for backwards compatibility. Environment variable: DISCORD_TOKEN_BOT. Default: "False".
#   -h|--help         Shows help text.
# 1022054381870395432
# Option --after expects a single argument, but provided with multiple:
# <2023-04-02> <23:59>
# DiscordChatExporter.Cli v2.39.1
#
# USAGE
#   dotnet DiscordChatExporter.Cli.dll export --channel <values...> --token <value> [options]
#
# DESCRIPTION
#   Export one or multiple channels.
#
# OPTIONS
# * -c|--channel      Channel ID(s). If provided with category IDs, all channels inside those categories will be exported.
# * -t|--token        Authentication token. Environment variable: DISCORD_TOKEN.
#   -o|--output       Output file or directory path. If a directory is specified, file names will be generated automatically based on the channel names and other parameters. Directory path should end with a slash to avoid ambiguity. Supports template tokens, see the documentation for more info. Default: "e:\AI\miatiadev\miatiabot".
#   -f|--format       Export format. Choices: "PlainText", "HtmlDark", "HtmlLight", "Csv", "Json". Default: "HtmlDark".
#   --after           Only include messages sent after this date or message ID.
#   --before          Only include messages sent before this date or message ID.
#   -p|--partition    Split output into partitions, each limited to this number of messages (e.g. '100') or file size (e.g. '10mb').
#   --filter          Only include messages that satisfy this filter (e.g. 'from:foo#1234' or 'has:image').
#   --parallel        Limits how many channels can be exported in parallel. Default: "1".
#   --markdown        Process markdown, mentions, and other special tokens. Default: "True".
#   --media           Download assets referenced by the export (user avatars, attached files, embedded images, etc.). Default: "False".
#   --reuse-media     Reuse previously downloaded assets to avoid redundant requests. Default: "False".
#   --media-dir       Download assets to this directory. If not specified, the asset directory path will be derived from the output path.
#   --dateformat      Format used when writing dates. Default: "MM/dd/yyyy h:mm tt".
#   --fuck-russia     Don't print the Support Ukraine message to the console. Default: "False".
#   -b|--bot          This option doesn't do anything. Kept for backwards compatibility. Environment variable: DISCORD_TOKEN_BOT. Default: "False".
#   -h|--help         Shows help text.
# 1022054419510075402
# Option --after expects a single argument, but provided with multiple:
# <2023-04-02> <23:59>
# DiscordChatExporter.Cli v2.39.1
#
# USAGE
#   dotnet DiscordChatExporter.Cli.dll export --channel <values...> --token <value> [options]
#
# DESCRIPTION
#   Export one or multiple channels.
#
# OPTIONS
# * -c|--channel      Channel ID(s). If provided with category IDs, all channels inside those categories will be exported.
# * -t|--token        Authentication token. Environment variable: DISCORD_TOKEN.
#   -o|--output       Output file or directory path. If a directory is specified, file names will be generated automatically based on the channel names and other parameters. Directory path should end with a slash to avoid ambiguity. Supports template tokens, see the documentation for more info. Default: "e:\AI\miatiadev\miatiabot".
#   -f|--format       Export format. Choices: "PlainText", "HtmlDark", "HtmlLight", "Csv", "Json". Default: "HtmlDark".
#   --after           Only include messages sent after this date or message ID.
#   --before          Only include messages sent before this date or message ID.
#   -p|--partition    Split output into partitions, each limited to this number of messages (e.g. '100') or file size (e.g. '10mb').
#   --filter          Only include messages that satisfy this filter (e.g. 'from:foo#1234' or 'has:image').
#   --parallel        Limits how many channels can be exported in parallel. Default: "1".
#   --markdown        Process markdown, mentions, and other special tokens. Default: "True".
#   --media           Download assets referenced by the export (user avatars, attached files, embedded images, etc.). Default: "False".
#   --reuse-media     Reuse previously downloaded assets to avoid redundant requests. Default: "False".
#   --media-dir       Download assets to this directory. If not specified, the asset directory path will be derived from the output path.
#   --dateformat      Format used when writing dates. Default: "MM/dd/yyyy h:mm tt".
#   --fuck-russia     Don't print the Support Ukraine message to the console. Default: "False".
#   -b|--bot          This option doesn't do anything. Kept for backwards compatibility. Environment variable: DISCORD_TOKEN_BOT. Default: "False".
#   -h|--help         Shows help text.
# 1022745052944007198
# Option --after expects a single argument, but provided with multiple:
# <2023-04-02> <23:59>
# DiscordChatExporter.Cli v2.39.1
#
# USAGE
#   dotnet DiscordChatExporter.Cli.dll export --channel <values...> --token <value> [options]
#
# DESCRIPTION
#   Export one or multiple channels.
#
# OPTIONS
# * -c|--channel      Channel ID(s). If provided with category IDs, all channels inside those categories will be exported.
# * -t|--token        Authentication token. Environment variable: DISCORD_TOKEN.
#   -o|--output       Output file or directory path. If a directory is specified, file names will be generated automatically based on the channel names and other parameters. Directory path should end with a slash to avoid ambiguity. Supports template tokens, see the documentation for more info. Default: "e:\AI\miatiadev\miatiabot".
#   -f|--format       Export format. Choices: "PlainText", "HtmlDark", "HtmlLight", "Csv", "Json". Default: "HtmlDark".
#   --after           Only include messages sent after this date or message ID.
#   --before          Only include messages sent before this date or message ID.
#   -p|--partition    Split output into partitions, each limited to this number of messages (e.g. '100') or file size (e.g. '10mb').
#   --filter          Only include messages that satisfy this filter (e.g. 'from:foo#1234' or 'has:image').
#   --parallel        Limits how many channels can be exported in parallel. Default: "1".
#   --markdown        Process markdown, mentions, and other special tokens. Default: "True".
#   --media           Download assets referenced by the export (user avatars, attached files, embedded images, etc.). Default: "False".
#   --reuse-media     Reuse previously downloaded assets to avoid redundant requests. Default: "False".
#   --media-dir       Download assets to this directory. If not specified, the asset directory path will be derived from the output path.
#   --dateformat      Format used when writing dates. Default: "MM/dd/yyyy h:mm tt".
#   --fuck-russia     Don't print the Support Ukraine message to the console. Default: "False".
#   -b|--bot          This option doesn't do anything. Kept for backwards compatibility. Environment variable: DISCORD_TOKEN_BOT. Default: "False".
#   -h|--help         Shows help text.
# 1044842408602513448
# Option --after expects a single argument, but provided with multiple:
# <2023-04-02> <23:59>
# DiscordChatExporter.Cli v2.39.1
#
# USAGE
#   dotnet DiscordChatExporter.Cli.dll export --channel <values...> --token <value> [options]
#
# DESCRIPTION
#   Export one or multiple channels.
#
# OPTIONS
# * -c|--channel      Channel ID(s). If provided with category IDs, all channels inside those categories will be exported.
# * -t|--token        Authentication token. Environment variable: DISCORD_TOKEN.
#   -o|--output       Output file or directory path. If a directory is specified, file names will be generated automatically based on the channel names and other parameters. Directory path should end with a slash to avoid ambiguity. Supports template tokens, see the documentation for more info. Default: "e:\AI\miatiadev\miatiabot".
#   -f|--format       Export format. Choices: "PlainText", "HtmlDark", "HtmlLight", "Csv", "Json". Default: "HtmlDark".
#   --after           Only include messages sent after this date or message ID.
#   --before          Only include messages sent before this date or message ID.
#   -p|--partition    Split output into partitions, each limited to this number of messages (e.g. '100') or file size (e.g. '10mb').
#   --filter          Only include messages that satisfy this filter (e.g. 'from:foo#1234' or 'has:image').
#   --parallel        Limits how many channels can be exported in parallel. Default: "1".
#   --markdown        Process markdown, mentions, and other special tokens. Default: "True".
#   --media           Download assets referenced by the export (user avatars, attached files, embedded images, etc.). Default: "False".
#   --reuse-media     Reuse previously downloaded assets to avoid redundant requests. Default: "False".
#   --media-dir       Download assets to this directory. If not specified, the asset directory path will be derived from the output path.
#   --dateformat      Format used when writing dates. Default: "MM/dd/yyyy h:mm tt".
#   --fuck-russia     Don't print the Support Ukraine message to the console. Default: "False".
#   -b|--bot          This option doesn't do anything. Kept for backwards compatibility. Environment variable: DISCORD_TOKEN_BOT. Default: "False".
#   -h|--help         Shows help text.
# 1045601907823087626
# Option --after expects a single argument, but provided with multiple:
# <2023-04-02> <23:59>
# DiscordChatExporter.Cli v2.39.1
#
# USAGE
#   dotnet DiscordChatExporter.Cli.dll export --channel <values...> --token <value> [options]
#
# DESCRIPTION
#   Export one or multiple channels.
#
# OPTIONS
# * -c|--channel      Channel ID(s). If provided with category IDs, all channels inside those categories will be exported.
# * -t|--token        Authentication token. Environment variable: DISCORD_TOKEN.
#   -o|--output       Output file or directory path. If a directory is specified, file names will be generated automatically based on the channel names and other parameters. Directory path should end with a slash to avoid ambiguity. Supports template tokens, see the documentation for more info. Default: "e:\AI\miatiadev\miatiabot".
#   -f|--format       Export format. Choices: "PlainText", "HtmlDark", "HtmlLight", "Csv", "Json". Default: "HtmlDark".
#   --after           Only include messages sent after this date or message ID.
#   --before          Only include messages sent before this date or message ID.
#   -p|--partition    Split output into partitions, each limited to this number of messages (e.g. '100') or file size (e.g. '10mb').
#   --filter          Only include messages that satisfy this filter (e.g. 'from:foo#1234' or 'has:image').
#   --parallel        Limits how many channels can be exported in parallel. Default: "1".
#   --markdown        Process markdown, mentions, and other special tokens. Default: "True".
#   --media           Download assets referenced by the export (user avatars, attached files, embedded images, etc.). Default: "False".
#   --reuse-media     Reuse previously downloaded assets to avoid redundant requests. Default: "False".
#   --media-dir       Download assets to this directory. If not specified, the asset directory path will be derived from the output path.
#   --dateformat      Format used when writing dates. Default: "MM/dd/yyyy h:mm tt".
#   --fuck-russia     Don't print the Support Ukraine message to the console. Default: "False".
#   -b|--bot          This option doesn't do anything. Kept for backwards compatibility. Environment variable: DISCORD_TOKEN_BOT. Default: "False".
#   -h|--help         Shows help text.
# 1045601954576994354
# Option --after expects a single argument, but provided with multiple:
# <2023-04-02> <23:59>
# DiscordChatExporter.Cli v2.39.1
#
# USAGE
#   dotnet DiscordChatExporter.Cli.dll export --channel <values...> --token <value> [options]
#
# DESCRIPTION
#   Export one or multiple channels.
#
# OPTIONS
# * -c|--channel      Channel ID(s). If provided with category IDs, all channels inside those categories will be exported.
# * -t|--token        Authentication token. Environment variable: DISCORD_TOKEN.
#   -o|--output       Output file or directory path. If a directory is specified, file names will be generated automatically based on the channel names and other parameters. Directory path should end with a slash to avoid ambiguity. Supports template tokens, see the documentation for more info. Default: "e:\AI\miatiadev\miatiabot".
#   -f|--format       Export format. Choices: "PlainText", "HtmlDark", "HtmlLight", "Csv", "Json". Default: "HtmlDark".
#   --after           Only include messages sent after this date or message ID.
#   --before          Only include messages sent before this date or message ID.
#   -p|--partition    Split output into partitions, each limited to this number of messages (e.g. '100') or file size (e.g. '10mb').
#   --filter          Only include messages that satisfy this filter (e.g. 'from:foo#1234' or 'has:image').
#   --parallel        Limits how many channels can be exported in parallel. Default: "1".
#   --markdown        Process markdown, mentions, and other special tokens. Default: "True".
#   --media           Download assets referenced by the export (user avatars, attached files, embedded images, etc.). Default: "False".
#   --reuse-media     Reuse previously downloaded assets to avoid redundant requests. Default: "False".
#   --media-dir       Download assets to this directory. If not specified, the asset directory path will be derived from the output path.
#   --dateformat      Format used when writing dates. Default: "MM/dd/yyyy h:mm tt".
#   --fuck-russia     Don't print the Support Ukraine message to the console. Default: "False".
#   -b|--bot          This option doesn't do anything. Kept for backwards compatibility. Environment variable: DISCORD_TOKEN_BOT. Default: "False".
#   -h|--help         Shows help text.
# 1045602394425282580
# Option --after expects a single argument, but provided with multiple:
# <2023-04-02> <23:59>
# DiscordChatExporter.Cli v2.39.1
#
# USAGE
#   dotnet DiscordChatExporter.Cli.dll export --channel <values...> --token <value> [options]
#
# DESCRIPTION
#   Export one or multiple channels.
#
# OPTIONS
# * -c|--channel      Channel ID(s). If provided with category IDs, all channels inside those categories will be exported.
# * -t|--token        Authentication token. Environment variable: DISCORD_TOKEN.
#   -o|--output       Output file or directory path. If a directory is specified, file names will be generated automatically based on the channel names and other parameters. Directory path should end with a slash to avoid ambiguity. Supports template tokens, see the documentation for more info. Default: "e:\AI\miatiadev\miatiabot".
#   -f|--format       Export format. Choices: "PlainText", "HtmlDark", "HtmlLight", "Csv", "Json". Default: "HtmlDark".
#   --after           Only include messages sent after this date or message ID.
#   --before          Only include messages sent before this date or message ID.
#   -p|--partition    Split output into partitions, each limited to this number of messages (e.g. '100') or file size (e.g. '10mb').
#   --filter          Only include messages that satisfy this filter (e.g. 'from:foo#1234' or 'has:image').
#   --parallel        Limits how many channels can be exported in parallel. Default: "1".
#   --markdown        Process markdown, mentions, and other special tokens. Default: "True".
#   --media           Download assets referenced by the export (user avatars, attached files, embedded images, etc.). Default: "False".
#   --reuse-media     Reuse previously downloaded assets to avoid redundant requests. Default: "False".
#   --media-dir       Download assets to this directory. If not specified, the asset directory path will be derived from the output path.
#   --dateformat      Format used when writing dates. Default: "MM/dd/yyyy h:mm tt".
#   --fuck-russia     Don't print the Support Ukraine message to the console. Default: "False".
#   -b|--bot          This option doesn't do anything. Kept for backwards compatibility. Environment variable: DISCORD_TOKEN_BOT. Default: "False".
#   -h|--help         Shows help text.
# 1046289365619458108
# Option --after expects a single argument, but provided with multiple:
# <2023-04-02> <23:59>
# DiscordChatExporter.Cli v2.39.1
#
# USAGE
#   dotnet DiscordChatExporter.Cli.dll export --channel <values...> --token <value> [options]
#
# DESCRIPTION
#   Export one or multiple channels.
#
# OPTIONS
# * -c|--channel      Channel ID(s). If provided with category IDs, all channels inside those categories will be exported.
# * -t|--token        Authentication token. Environment variable: DISCORD_TOKEN.
#   -o|--output       Output file or directory path. If a directory is specified, file names will be generated automatically based on the channel names and other parameters. Directory path should end with a slash to avoid ambiguity. Supports template tokens, see the documentation for more info. Default: "e:\AI\miatiadev\miatiabot".
#   -f|--format       Export format. Choices: "PlainText", "HtmlDark", "HtmlLight", "Csv", "Json". Default: "HtmlDark".
#   --after           Only include messages sent after this date or message ID.
#   --before          Only include messages sent before this date or message ID.
#   -p|--partition    Split output into partitions, each limited to this number of messages (e.g. '100') or file size (e.g. '10mb').
#   --filter          Only include messages that satisfy this filter (e.g. 'from:foo#1234' or 'has:image').
#   --parallel        Limits how many channels can be exported in parallel. Default: "1".
#   --markdown        Process markdown, mentions, and other special tokens. Default: "True".
#   --media           Download assets referenced by the export (user avatars, attached files, embedded images, etc.). Default: "False".
#   --reuse-media     Reuse previously downloaded assets to avoid redundant requests. Default: "False".
#   --media-dir       Download assets to this directory. If not specified, the asset directory path will be derived from the output path.
#   --dateformat      Format used when writing dates. Default: "MM/dd/yyyy h:mm tt".
#   --fuck-russia     Don't print the Support Ukraine message to the console. Default: "False".
#   -b|--bot          This option doesn't do anything. Kept for backwards compatibility. Environment variable: DISCORD_TOKEN_BOT. Default: "False".
#   -h|--help         Shows help text.
# 1046289392974704660
# Option --after expects a single argument, but provided with multiple:
# <2023-04-02> <23:59>
# DiscordChatExporter.Cli v2.39.1
#
# USAGE
#   dotnet DiscordChatExporter.Cli.dll export --channel <values...> --token <value> [options]
#
# DESCRIPTION
#   Export one or multiple channels.
#
# OPTIONS
# * -c|--channel      Channel ID(s). If provided with category IDs, all channels inside those categories will be exported.
# * -t|--token        Authentication token. Environment variable: DISCORD_TOKEN.
#   -o|--output       Output file or directory path. If a directory is specified, file names will be generated automatically based on the channel names and other parameters. Directory path should end with a slash to avoid ambiguity. Supports template tokens, see the documentation for more info. Default: "e:\AI\miatiadev\miatiabot".
#   -f|--format       Export format. Choices: "PlainText", "HtmlDark", "HtmlLight", "Csv", "Json". Default: "HtmlDark".
#   --after           Only include messages sent after this date or message ID.
#   --before          Only include messages sent before this date or message ID.
#   -p|--partition    Split output into partitions, each limited to this number of messages (e.g. '100') or file size (e.g. '10mb').
#   --filter          Only include messages that satisfy this filter (e.g. 'from:foo#1234' or 'has:image').
#   --parallel        Limits how many channels can be exported in parallel. Default: "1".
#   --markdown        Process markdown, mentions, and other special tokens. Default: "True".
#   --media           Download assets referenced by the export (user avatars, attached files, embedded images, etc.). Default: "False".
#   --reuse-media     Reuse previously downloaded assets to avoid redundant requests. Default: "False".
#   --media-dir       Download assets to this directory. If not specified, the asset directory path will be derived from the output path.
#   --dateformat      Format used when writing dates. Default: "MM/dd/yyyy h:mm tt".
#   --fuck-russia     Don't print the Support Ukraine message to the console. Default: "False".
#   -b|--bot          This option doesn't do anything. Kept for backwards compatibility. Environment variable: DISCORD_TOKEN_BOT. Default: "False".
#   -h|--help         Shows help text.
# 1046289486126002246
# Option --after expects a single argument, but provided with multiple:
# <2023-04-02> <23:59>
# DiscordChatExporter.Cli v2.39.1
#
# USAGE
#   dotnet DiscordChatExporter.Cli.dll export --channel <values...> --token <value> [options]
#
# DESCRIPTION
#   Export one or multiple channels.
#
# OPTIONS
# * -c|--channel      Channel ID(s). If provided with category IDs, all channels inside those categories will be exported.
# * -t|--token        Authentication token. Environment variable: DISCORD_TOKEN.
#   -o|--output       Output file or directory path. If a directory is specified, file names will be generated automatically based on the channel names and other parameters. Directory path should end with a slash to avoid ambiguity. Supports template tokens, see the documentation for more info. Default: "e:\AI\miatiadev\miatiabot".
#   -f|--format       Export format. Choices: "PlainText", "HtmlDark", "HtmlLight", "Csv", "Json". Default: "HtmlDark".
#   --after           Only include messages sent after this date or message ID.
#   --before          Only include messages sent before this date or message ID.
#   -p|--partition    Split output into partitions, each limited to this number of messages (e.g. '100') or file size (e.g. '10mb').
#   --filter          Only include messages that satisfy this filter (e.g. 'from:foo#1234' or 'has:image').
#   --parallel        Limits how many channels can be exported in parallel. Default: "1".
#   --markdown        Process markdown, mentions, and other special tokens. Default: "True".
#   --media           Download assets referenced by the export (user avatars, attached files, embedded images, etc.). Default: "False".
#   --reuse-media     Reuse previously downloaded assets to avoid redundant requests. Default: "False".
#   --media-dir       Download assets to this directory. If not specified, the asset directory path will be derived from the output path.
#   --dateformat      Format used when writing dates. Default: "MM/dd/yyyy h:mm tt".
#   --fuck-russia     Don't print the Support Ukraine message to the console. Default: "False".
#   -b|--bot          This option doesn't do anything. Kept for backwards compatibility. Environment variable: DISCORD_TOKEN_BOT. Default: "False".
#   -h|--help         Shows help text.
# 1046289514026516520
# Option --after expects a single argument, but provided with multiple:
# <2023-04-02> <23:59>
# DiscordChatExporter.Cli v2.39.1
#
# USAGE
#   dotnet DiscordChatExporter.Cli.dll export --channel <values...> --token <value> [options]
#
# DESCRIPTION
#   Export one or multiple channels.
#
# OPTIONS
# * -c|--channel      Channel ID(s). If provided with category IDs, all channels inside those categories will be exported.
# * -t|--token        Authentication token. Environment variable: DISCORD_TOKEN.
#   -o|--output       Output file or directory path. If a directory is specified, file names will be generated automatically based on the channel names and other parameters. Directory path should end with a slash to avoid ambiguity. Supports template tokens, see the documentation for more info. Default: "e:\AI\miatiadev\miatiabot".
#   -f|--format       Export format. Choices: "PlainText", "HtmlDark", "HtmlLight", "Csv", "Json". Default: "HtmlDark".
#   --after           Only include messages sent after this date or message ID.
#   --before          Only include messages sent before this date or message ID.
#   -p|--partition    Split output into partitions, each limited to this number of messages (e.g. '100') or file size (e.g. '10mb').
#   --filter          Only include messages that satisfy this filter (e.g. 'from:foo#1234' or 'has:image').
#   --parallel        Limits how many channels can be exported in parallel. Default: "1".
#   --markdown        Process markdown, mentions, and other special tokens. Default: "True".
#   --media           Download assets referenced by the export (user avatars, attached files, embedded images, etc.). Default: "False".
#   --reuse-media     Reuse previously downloaded assets to avoid redundant requests. Default: "False".
#   --media-dir       Download assets to this directory. If not specified, the asset directory path will be derived from the output path.
#   --dateformat      Format used when writing dates. Default: "MM/dd/yyyy h:mm tt".
#   --fuck-russia     Don't print the Support Ukraine message to the console. Default: "False".
#   -b|--bot          This option doesn't do anything. Kept for backwards compatibility. Environment variable: DISCORD_TOKEN_BOT. Default: "False".
#   -h|--help         Shows help text.
# 1051067660013674496
# Option --after expects a single argument, but provided with multiple:
# <2023-04-02> <23:59>
# DiscordChatExporter.Cli v2.39.1
#
# USAGE
#   dotnet DiscordChatExporter.Cli.dll export --channel <values...> --token <value> [options]
#
# DESCRIPTION
#   Export one or multiple channels.
#
# OPTIONS
# * -c|--channel      Channel ID(s). If provided with category IDs, all channels inside those categories will be exported.
# * -t|--token        Authentication token. Environment variable: DISCORD_TOKEN.
#   -o|--output       Output file or directory path. If a directory is specified, file names will be generated automatically based on the channel names and other parameters. Directory path should end with a slash to avoid ambiguity. Supports template tokens, see the documentation for more info. Default: "e:\AI\miatiadev\miatiabot".
#   -f|--format       Export format. Choices: "PlainText", "HtmlDark", "HtmlLight", "Csv", "Json". Default: "HtmlDark".
#   --after           Only include messages sent after this date or message ID.
#   --before          Only include messages sent before this date or message ID.
#   -p|--partition    Split output into partitions, each limited to this number of messages (e.g. '100') or file size (e.g. '10mb').
#   --filter          Only include messages that satisfy this filter (e.g. 'from:foo#1234' or 'has:image').
#   --parallel        Limits how many channels can be exported in parallel. Default: "1".
#   --markdown        Process markdown, mentions, and other special tokens. Default: "True".
#   --media           Download assets referenced by the export (user avatars, attached files, embedded images, etc.). Default: "False".
#   --reuse-media     Reuse previously downloaded assets to avoid redundant requests. Default: "False".
#   --media-dir       Download assets to this directory. If not specified, the asset directory path will be derived from the output path.
#   --dateformat      Format used when writing dates. Default: "MM/dd/yyyy h:mm tt".
#   --fuck-russia     Don't print the Support Ukraine message to the console. Default: "False".
#   -b|--bot          This option doesn't do anything. Kept for backwards compatibility. Environment variable: DISCORD_TOKEN_BOT. Default: "False".
#   -h|--help         Shows help text.
# 1051067680255393862
# Option --after expects a single argument, but provided with multiple:
# <2023-04-02> <23:59>
# DiscordChatExporter.Cli v2.39.1
#
# USAGE
#   dotnet DiscordChatExporter.Cli.dll export --channel <values...> --token <value> [options]
#
# DESCRIPTION
#   Export one or multiple channels.
#
# OPTIONS
# * -c|--channel      Channel ID(s). If provided with category IDs, all channels inside those categories will be exported.
# * -t|--token        Authentication token. Environment variable: DISCORD_TOKEN.
#   -o|--output       Output file or directory path. If a directory is specified, file names will be generated automatically based on the channel names and other parameters. Directory path should end with a slash to avoid ambiguity. Supports template tokens, see the documentation for more info. Default: "e:\AI\miatiadev\miatiabot".
#   -f|--format       Export format. Choices: "PlainText", "HtmlDark", "HtmlLight", "Csv", "Json". Default: "HtmlDark".
#   --after           Only include messages sent after this date or message ID.
#   --before          Only include messages sent before this date or message ID.
#   -p|--partition    Split output into partitions, each limited to this number of messages (e.g. '100') or file size (e.g. '10mb').
#   --filter          Only include messages that satisfy this filter (e.g. 'from:foo#1234' or 'has:image').
#   --parallel        Limits how many channels can be exported in parallel. Default: "1".
#   --markdown        Process markdown, mentions, and other special tokens. Default: "True".
#   --media           Download assets referenced by the export (user avatars, attached files, embedded images, etc.). Default: "False".
#   --reuse-media     Reuse previously downloaded assets to avoid redundant requests. Default: "False".
#   --media-dir       Download assets to this directory. If not specified, the asset directory path will be derived from the output path.
#   --dateformat      Format used when writing dates. Default: "MM/dd/yyyy h:mm tt".
#   --fuck-russia     Don't print the Support Ukraine message to the console. Default: "False".
#   -b|--bot          This option doesn't do anything. Kept for backwards compatibility. Environment variable: DISCORD_TOKEN_BOT. Default: "False".
#   -h|--help         Shows help text.
# 1051067701960921129
# Option --after expects a single argument, but provided with multiple:
# <2023-04-02> <23:59>
# DiscordChatExporter.Cli v2.39.1
#
# USAGE
#   dotnet DiscordChatExporter.Cli.dll export --channel <values...> --token <value> [options]
#
# DESCRIPTION
#   Export one or multiple channels.
#
# OPTIONS
# * -c|--channel      Channel ID(s). If provided with category IDs, all channels inside those categories will be exported.
# * -t|--token        Authentication token. Environment variable: DISCORD_TOKEN.
#   -o|--output       Output file or directory path. If a directory is specified, file names will be generated automatically based on the channel names and other parameters. Directory path should end with a slash to avoid ambiguity. Supports template tokens, see the documentation for more info. Default: "e:\AI\miatiadev\miatiabot".
#   -f|--format       Export format. Choices: "PlainText", "HtmlDark", "HtmlLight", "Csv", "Json". Default: "HtmlDark".
#   --after           Only include messages sent after this date or message ID.
#   --before          Only include messages sent before this date or message ID.
#   -p|--partition    Split output into partitions, each limited to this number of messages (e.g. '100') or file size (e.g. '10mb').
#   --filter          Only include messages that satisfy this filter (e.g. 'from:foo#1234' or 'has:image').
#   --parallel        Limits how many channels can be exported in parallel. Default: "1".
#   --markdown        Process markdown, mentions, and other special tokens. Default: "True".
#   --media           Download assets referenced by the export (user avatars, attached files, embedded images, etc.). Default: "False".
#   --reuse-media     Reuse previously downloaded assets to avoid redundant requests. Default: "False".
#   --media-dir       Download assets to this directory. If not specified, the asset directory path will be derived from the output path.
#   --dateformat      Format used when writing dates. Default: "MM/dd/yyyy h:mm tt".
#   --fuck-russia     Don't print the Support Ukraine message to the console. Default: "False".
#   -b|--bot          This option doesn't do anything. Kept for backwards compatibility. Environment variable: DISCORD_TOKEN_BOT. Default: "False".
#   -h|--help         Shows help text.
# 1051067740665946132
# Option --after expects a single argument, but provided with multiple:
# <2023-04-02> <23:59>
# DiscordChatExporter.Cli v2.39.1
#
# USAGE
#   dotnet DiscordChatExporter.Cli.dll export --channel <values...> --token <value> [options]
#
# DESCRIPTION
#   Export one or multiple channels.
#
# OPTIONS
# * -c|--channel      Channel ID(s). If provided with category IDs, all channels inside those categories will be exported.
# * -t|--token        Authentication token. Environment variable: DISCORD_TOKEN.
#   -o|--output       Output file or directory path. If a directory is specified, file names will be generated automatically based on the channel names and other parameters. Directory path should end with a slash to avoid ambiguity. Supports template tokens, see the documentation for more info. Default: "e:\AI\miatiadev\miatiabot".
#   -f|--format       Export format. Choices: "PlainText", "HtmlDark", "HtmlLight", "Csv", "Json". Default: "HtmlDark".
#   --after           Only include messages sent after this date or message ID.
#   --before          Only include messages sent before this date or message ID.
#   -p|--partition    Split output into partitions, each limited to this number of messages (e.g. '100') or file size (e.g. '10mb').
#   --filter          Only include messages that satisfy this filter (e.g. 'from:foo#1234' or 'has:image').
#   --parallel        Limits how many channels can be exported in parallel. Default: "1".
#   --markdown        Process markdown, mentions, and other special tokens. Default: "True".
#   --media           Download assets referenced by the export (user avatars, attached files, embedded images, etc.). Default: "False".
#   --reuse-media     Reuse previously downloaded assets to avoid redundant requests. Default: "False".
#   --media-dir       Download assets to this directory. If not specified, the asset directory path will be derived from the output path.
#   --dateformat      Format used when writing dates. Default: "MM/dd/yyyy h:mm tt".
#   --fuck-russia     Don't print the Support Ukraine message to the console. Default: "False".
#   -b|--bot          This option doesn't do anything. Kept for backwards compatibility. Environment variable: DISCORD_TOKEN_BOT. Default: "False".
#   -h|--help         Shows help text.
# 1051067777881997403
# Option --after expects a single argument, but provided with multiple:
# <2023-04-02> <23:59>
# 1051067796102053938
# Option --after expects a single argument, but provided with multiple:
# <2023-04-02> <23:59>
# DiscordChatExporter.Cli v2.39.1
#
# USAGE
#   dotnet DiscordChatExporter.Cli.dll export --channel <values...> --token <value> [options]
#
# DESCRIPTION
#   Export one or multiple channels.
#
# OPTIONS
# * -c|--channel      Channel ID(s). If provided with category IDs, all channels inside those categories will be exported.
# * -t|--token        Authentication token. Environment variable: DISCORD_TOKEN.
#   -o|--output       Output file or directory path. If a directory is specified, file names will be generated automatically based on the channel names and other parameters. Directory path should end with a slash to avoid ambiguity. Supports template tokens, see the documentation for more info. Default: "e:\AI\miatiadev\miatiabot".
#   -f|--format       Export format. Choices: "PlainText", "HtmlDark", "HtmlLight", "Csv", "Json". Default: "HtmlDark".
#   --after           Only include messages sent after this date or message ID.
#   --before          Only include messages sent before this date or message ID.
#   -p|--partition    Split output into partitions, each limited to this number of messages (e.g. '100') or file size (e.g. '10mb').
#   --filter          Only include messages that satisfy this filter (e.g. 'from:foo#1234' or 'has:image').
#   --parallel        Limits how many channels can be exported in parallel. Default: "1".
#   --markdown        Process markdown, mentions, and other special tokens. Default: "True".
#   --media           Download assets referenced by the export (user avatars, attached files, embedded images, etc.). Default: "False".
#   --reuse-media     Reuse previously downloaded assets to avoid redundant requests. Default: "False".
#   --media-dir       Download assets to this directory. If not specified, the asset directory path will be derived from the output path.
#   --dateformat      Format used when writing dates. Default: "MM/dd/yyyy h:mm tt".
#   --fuck-russia     Don't print the Support Ukraine message to the console. Default: "False".
#   -b|--bot          This option doesn't do anything. Kept for backwards compatibility. Environment variable: DISCORD_TOKEN_BOT. Default: "False".
#   -h|--help         Shows help text.
#
# DiscordChatExporter.Cli v2.39.1
#
# USAGE
#   dotnet DiscordChatExporter.Cli.dll export --channel <values...> --token <value> [options]
#
# DESCRIPTION
#   Export one or multiple channels.
#
# OPTIONS
# * -c|--channel      Channel ID(s). If provided with category IDs, all channels inside those categories will be exported.
# * -t|--token        Authentication token. Environment variable: DISCORD_TOKEN.
#   -o|--output       Output file or directory path. If a directory is specified, file names will be generated automatically based on the channel names and other parameters. Directory path should end with a slash to avoid ambiguity. Supports template tokens, see the documentation for more info. Default: "e:\AI\miatiadev\miatiabot".
#   -f|--format       Export format. Choices: "PlainText", "HtmlDark", "HtmlLight", "Csv", "Json". Default: "HtmlDark".
#   --after           Only include messages sent after this date or message ID.
#   --before          Only include messages sent before this date or message ID.
#   -p|--partition    Split output into partitions, each limited to this number of messages (e.g. '100') or file size (e.g. '10mb').
#   --filter          Only include messages that satisfy this filter (e.g. 'from:foo#1234' or 'has:image').
#   --parallel        Limits how many channels can be exported in parallel. Default: "1".
#   --markdown        Process markdown, mentions, and other special tokens. Default: "True".
#   --media           Download assets referenced by the export (user avatars, attached files, embedded images, etc.). Default: "False".
#   --reuse-media     Reuse previously downloaded assets to avoid redundant requests. Default: "False".
#   --media-dir       Download assets to this directory. If not specified, the asset directory path will be derived from the output path.
#   --dateformat      Format used when writing dates. Default: "MM/dd/yyyy h:mm tt".
#   --fuck-russia     Don't print the Support Ukraine message to the console. Default: "False".
#   -b|--bot          This option doesn't do anything. Kept for backwards compatibility. Environment variable: DISCORD_TOKEN_BOT. Default: "False".
#   -h|--help         Shows help text.
# 1051067814305333268
# Option --after expects a single argument, but provided with multiple:
# <2023-04-02> <23:59>
# DiscordChatExporter.Cli v2.39.1
#
# USAGE
#   dotnet DiscordChatExporter.Cli.dll export --channel <values...> --token <value> [options]
#
# DESCRIPTION
#   Export one or multiple channels.
#
# OPTIONS
# * -c|--channel      Channel ID(s). If provided with category IDs, all channels inside those categories will be exported.
# * -t|--token        Authentication token. Environment variable: DISCORD_TOKEN.
#   -o|--output       Output file or directory path. If a directory is specified, file names will be generated automatically based on the channel names and other parameters. Directory path should end with a slash to avoid ambiguity. Supports template tokens, see the documentation for more info. Default: "e:\AI\miatiadev\miatiabot".
#   -f|--format       Export format. Choices: "PlainText", "HtmlDark", "HtmlLight", "Csv", "Json". Default: "HtmlDark".
#   --after           Only include messages sent after this date or message ID.
#   --before          Only include messages sent before this date or message ID.
#   -p|--partition    Split output into partitions, each limited to this number of messages (e.g. '100') or file size (e.g. '10mb').
#   --filter          Only include messages that satisfy this filter (e.g. 'from:foo#1234' or 'has:image').
#   --parallel        Limits how many channels can be exported in parallel. Default: "1".
#   --markdown        Process markdown, mentions, and other special tokens. Default: "True".
#   --media           Download assets referenced by the export (user avatars, attached files, embedded images, etc.). Default: "False".
#   --reuse-media     Reuse previously downloaded assets to avoid redundant requests. Default: "False".
#   --media-dir       Download assets to this directory. If not specified, the asset directory path will be derived from the output path.
#   --dateformat      Format used when writing dates. Default: "MM/dd/yyyy h:mm tt".
#   --fuck-russia     Don't print the Support Ukraine message to the console. Default: "False".
#   -b|--bot          This option doesn't do anything. Kept for backwards compatibility. Environment variable: DISCORD_TOKEN_BOT. Default: "False".
#   -h|--help         Shows help text.
# 1051067840976916530
# Option --after expects a single argument, but provided with multiple:
# <2023-04-02> <23:59>
# DiscordChatExporter.Cli v2.39.1
#
# USAGE
#   dotnet DiscordChatExporter.Cli.dll export --channel <values...> --token <value> [options]
#
# DESCRIPTION
#   Export one or multiple channels.
#
# OPTIONS
# * -c|--channel      Channel ID(s). If provided with category IDs, all channels inside those categories will be exported.
# * -t|--token        Authentication token. Environment variable: DISCORD_TOKEN.
#   -o|--output       Output file or directory path. If a directory is specified, file names will be generated automatically based on the channel names and other parameters. Directory path should end with a slash to avoid ambiguity. Supports template tokens, see the documentation for more info. Default: "e:\AI\miatiadev\miatiabot".
#   -f|--format       Export format. Choices: "PlainText", "HtmlDark", "HtmlLight", "Csv", "Json". Default: "HtmlDark".
#   --after           Only include messages sent after this date or message ID.
#   --before          Only include messages sent before this date or message ID.
#   -p|--partition    Split output into partitions, each limited to this number of messages (e.g. '100') or file size (e.g. '10mb').
#   --filter          Only include messages that satisfy this filter (e.g. 'from:foo#1234' or 'has:image').
#   --parallel        Limits how many channels can be exported in parallel. Default: "1".
#   --markdown        Process markdown, mentions, and other special tokens. Default: "True".
#   --media           Download assets referenced by the export (user avatars, attached files, embedded images, etc.). Default: "False".
#   --reuse-media     Reuse previously downloaded assets to avoid redundant requests. Default: "False".
#   --media-dir       Download assets to this directory. If not specified, the asset directory path will be derived from the output path.
#   --dateformat      Format used when writing dates. Default: "MM/dd/yyyy h:mm tt".
#   --fuck-russia     Don't print the Support Ukraine message to the console. Default: "False".
#   -b|--bot          This option doesn't do anything. Kept for backwards compatibility. Environment variable: DISCORD_TOKEN_BOT. Default: "False".
#   -h|--help         Shows help text.
# 1054962536002371604
# Option --after expects a single argument, but provided with multiple:
# <2023-04-02> <23:59>
# DiscordChatExporter.Cli v2.39.1
#
# USAGE
#   dotnet DiscordChatExporter.Cli.dll export --channel <values...> --token <value> [options]
#
# DESCRIPTION
#   Export one or multiple channels.
#
# OPTIONS
# * -c|--channel      Channel ID(s). If provided with category IDs, all channels inside those categories will be exported.
# * -t|--token        Authentication token. Environment variable: DISCORD_TOKEN.
#   -o|--output       Output file or directory path. If a directory is specified, file names will be generated automatically based on the channel names and other parameters. Directory path should end with a slash to avoid ambiguity. Supports template tokens, see the documentation for more info. Default: "e:\AI\miatiadev\miatiabot".
#   -f|--format       Export format. Choices: "PlainText", "HtmlDark", "HtmlLight", "Csv", "Json". Default: "HtmlDark".
#   --after           Only include messages sent after this date or message ID.
#   --before          Only include messages sent before this date or message ID.
#   -p|--partition    Split output into partitions, each limited to this number of messages (e.g. '100') or file size (e.g. '10mb').
#   --filter          Only include messages that satisfy this filter (e.g. 'from:foo#1234' or 'has:image').
#   --parallel        Limits how many channels can be exported in parallel. Default: "1".
#   --markdown        Process markdown, mentions, and other special tokens. Default: "True".
#   --media           Download assets referenced by the export (user avatars, attached files, embedded images, etc.). Default: "False".
#   --reuse-media     Reuse previously downloaded assets to avoid redundant requests. Default: "False".
#   --media-dir       Download assets to this directory. If not specified, the asset directory path will be derived from the output path.
#   --dateformat      Format used when writing dates. Default: "MM/dd/yyyy h:mm tt".
#   --fuck-russia     Don't print the Support Ukraine message to the console. Default: "False".
#   -b|--bot          This option doesn't do anything. Kept for backwards compatibility. Environment variable: DISCORD_TOKEN_BOT. Default: "False".
#   -h|--help         Shows help text.
# 1054962560941694997
# Option --after expects a single argument, but provided with multiple:
# <2023-04-02> <23:59>
# DiscordChatExporter.Cli v2.39.1
#
# USAGE
#   dotnet DiscordChatExporter.Cli.dll export --channel <values...> --token <value> [options]
#
# DESCRIPTION
#   Export one or multiple channels.
#
# OPTIONS
# * -c|--channel      Channel ID(s). If provided with category IDs, all channels inside those categories will be exported.
# * -t|--token        Authentication token. Environment variable: DISCORD_TOKEN.
#   -o|--output       Output file or directory path. If a directory is specified, file names will be generated automatically based on the channel names and other parameters. Directory path should end with a slash to avoid ambiguity. Supports template tokens, see the documentation for more info. Default: "e:\AI\miatiadev\miatiabot".
#   -f|--format       Export format. Choices: "PlainText", "HtmlDark", "HtmlLight", "Csv", "Json". Default: "HtmlDark".
#   --after           Only include messages sent after this date or message ID.
#   --before          Only include messages sent before this date or message ID.
#   -p|--partition    Split output into partitions, each limited to this number of messages (e.g. '100') or file size (e.g. '10mb').
#   --filter          Only include messages that satisfy this filter (e.g. 'from:foo#1234' or 'has:image').
#   --parallel        Limits how many channels can be exported in parallel. Default: "1".
#   --markdown        Process markdown, mentions, and other special tokens. Default: "True".
#   --media           Download assets referenced by the export (user avatars, attached files, embedded images, etc.). Default: "False".
#   --reuse-media     Reuse previously downloaded assets to avoid redundant requests. Default: "False".
#   --media-dir       Download assets to this directory. If not specified, the asset directory path will be derived from the output path.
#   --dateformat      Format used when writing dates. Default: "MM/dd/yyyy h:mm tt".
#   --fuck-russia     Don't print the Support Ukraine message to the console. Default: "False".
#   -b|--bot          This option doesn't do anything. Kept for backwards compatibility. Environment variable: DISCORD_TOKEN_BOT. Default: "False".
#   -h|--help         Shows help text.
# 1086322455003533322
# Option --after expects a single argument, but provided with multiple:
# <2023-04-02> <23:59>
# DiscordChatExporter.Cli v2.39.1
#
# USAGE
#   dotnet DiscordChatExporter.Cli.dll export --channel <values...> --token <value> [options]
#
# DESCRIPTION
#   Export one or multiple channels.
#
# OPTIONS
# * -c|--channel      Channel ID(s). If provided with category IDs, all channels inside those categories will be exported.
# * -t|--token        Authentication token. Environment variable: DISCORD_TOKEN.
#   -o|--output       Output file or directory path. If a directory is specified, file names will be generated automatically based on the channel names and other parameters. Directory path should end with a slash to avoid ambiguity. Supports template tokens, see the documentation for more info. Default: "e:\AI\miatiadev\miatiabot".
#   -f|--format       Export format. Choices: "PlainText", "HtmlDark", "HtmlLight", "Csv", "Json". Default: "HtmlDark".
#   --after           Only include messages sent after this date or message ID.
#   --before          Only include messages sent before this date or message ID.
#   -p|--partition    Split output into partitions, each limited to this number of messages (e.g. '100') or file size (e.g. '10mb').
#   --filter          Only include messages that satisfy this filter (e.g. 'from:foo#1234' or 'has:image').
#   --parallel        Limits how many channels can be exported in parallel. Default: "1".
#   --markdown        Process markdown, mentions, and other special tokens. Default: "True".
#   --media           Download assets referenced by the export (user avatars, attached files, embedded images, etc.). Default: "False".
#   --reuse-media     Reuse previously downloaded assets to avoid redundant requests. Default: "False".
#   --media-dir       Download assets to this directory. If not specified, the asset directory path will be derived from the output path.
#   --dateformat      Format used when writing dates. Default: "MM/dd/yyyy h:mm tt".
#   --fuck-russia     Don't print the Support Ukraine message to the console. Default: "False".
#   -b|--bot          This option doesn't do anything. Kept for backwards compatibility. Environment variable: DISCORD_TOKEN_BOT. Default: "False".
#   -h|--help         Shows help text.
# 1086325070080786573
# Option --after expects a single argument, but provided with multiple:
# <2023-04-02> <23:59>
# DiscordChatExporter.Cli v2.39.1
#
# USAGE
#   dotnet DiscordChatExporter.Cli.dll export --channel <values...> --token <value> [options]
#
# DESCRIPTION
#   Export one or multiple channels.
#
# OPTIONS
# * -c|--channel      Channel ID(s). If provided with category IDs, all channels inside those categories will be exported.
# * -t|--token        Authentication token. Environment variable: DISCORD_TOKEN.
#   -o|--output       Output file or directory path. If a directory is specified, file names will be generated automatically based on the channel names and other parameters. Directory path should end with a slash to avoid ambiguity. Supports template tokens, see the documentation for more info. Default: "e:\AI\miatiadev\miatiabot".
#   -f|--format       Export format. Choices: "PlainText", "HtmlDark", "HtmlLight", "Csv", "Json". Default: "HtmlDark".
#   --after           Only include messages sent after this date or message ID.
#   --before          Only include messages sent before this date or message ID.
#   -p|--partition    Split output into partitions, each limited to this number of messages (e.g. '100') or file size (e.g. '10mb').
#   --filter          Only include messages that satisfy this filter (e.g. 'from:foo#1234' or 'has:image').
#   --parallel        Limits how many channels can be exported in parallel. Default: "1".
#   --markdown        Process markdown, mentions, and other special tokens. Default: "True".
#   --media           Download assets referenced by the export (user avatars, attached files, embedded images, etc.). Default: "False".
#   --reuse-media     Reuse previously downloaded assets to avoid redundant requests. Default: "False".
#   --media-dir       Download assets to this directory. If not specified, the asset directory path will be derived from the output path.
#   --dateformat      Format used when writing dates. Default: "MM/dd/yyyy h:mm tt".
#   --fuck-russia     Don't print the Support Ukraine message to the console. Default: "False".
#   -b|--bot          This option doesn't do anything. Kept for backwards compatibility. Environment variable: DISCORD_TOKEN_BOT. Default: "False".
#   -h|--help         Shows help text.
# Option --after expects a single argument, but provided with multiple:
# <2023-04-02> <23:59>

# %% [markdown]
# ## テスト用

# %%
# 指定したチャンネルのみ落とす
path = r"E:\AI\miatiadev\miatiabot\Cli\DiscordChatExporter.Cli.dll"
output_path = r"E:\AI\miatiadev\miatiabot\frontend\exports\discord-mini1"
file_format = r"JSON"
channel_id = 9712678945623

from dotenv import dotenv_values
config = dotenv_values(".env")
token = config["BOT_TOKEN"]
print(token)

#!dotnet $path export -c $channel_id -f $file_format -t $token -o $output_path --media --reuse-media
