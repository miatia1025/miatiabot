# %%
active_and_topics ='''
[ '1091862409918025761', '1091862649320509440' ]
'''

archived = '''
[ '1091862553933643848' ]
'''

channels = '''
[
  '1091862261519351983',
  '1091862261519351984',
  '1091862473675653121',
  '1091863257616232600'
]
'''

# %%
import ast

merged_arr = ast.literal_eval(active_and_topics) + ast.literal_eval(archived) + ast.literal_eval(channels)
sorted_arr = sorted(merged_arr, key=int)

print(sorted_arr)

# %%
path = r"E:\AI\miatiadev\discord_ids\CLI\DiscordChatExporter.Cli.dll"
output_path = r"E:\AI\miatiadev\discord_ids\CLI\outputs"
file_format = r"JSON"

from dotenv import dotenv_values
config = dotenv_values(".env")
token = config["BOT_TOKEN"]
print(token)

for channel_id in sorted_arr:
    print(channel_id)
    # !dotnet $path export -c $channel_id -f $file_format -t $token -o $output_path --media --reuse-media
# Out:
# MTA5MTk5MzU0OTM2MjQzMDA1Mw.GVRlNk.reNPk7q3tPkCHkBnDeBcWyr4g3awbgUEBCn4U8
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 10
#       7 token = config["BOT_TOKEN"]
#       8 print(token)
# ---> 10 for channel_id in sorted_arr:
#      11     print(channel_id)
#      12     get_ipython().system('dotnet $path export -c $channel_id -f $file_format -t $token -o $output_path --media --reuse-media')
#
# NameError: name 'sorted_arr' is not defined

# %% [markdown]
# ## テスト用

# %%
# 指定したチャンネルのみ落とす
path = r"E:\AI\miatiadev\discord_ids\CLI\DiscordChatExporter.Cli.dll"
output_path = r"E:\AI\miatiadev\discord_ids\CLI\outputs"
file_format = r"JSON"
channel_id = 9712678945623

from dotenv import dotenv_values
config = dotenv_values(".env")
token = config["BOT_TOKEN"]
print(token)

#!dotnet $path export -c $channel_id -f $file_format -t $token -o $output_path --media --reuse-media
